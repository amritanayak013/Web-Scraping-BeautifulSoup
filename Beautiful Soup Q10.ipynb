# %% [raw]
# Q.10Write a python program to scrape ‘data scientist’ job listings for location ‘New Delhi’ from ‘Monster.com’. It should include all the jobs listed for the next 5 pages.

# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = 'https://www.monster.com/jobs/search/?q=Data-Scientist&where=New-Delhi'
page = requests.get(URL)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
# Find Elements by ID
results = soup.find(id='ResultsContainer')

# %%
print(results.prettify())
# Out:
# <div class="mux-custom-scroll" data-extend="left" data-mux="customScroll" data-target="html" id="ResultsContainer">
#  <div class="scrollable" id="ResultsScrollable">
#   <div class="mux-apas-ads" data-ads='[{"sizes":[1,1],"placementId":14162549,"id":"bad1"},{"sizes":[1,1],"placementId":14343737,"id":"bad2"},{"sizes":[728,90],"placementId":14343738,"id":"bad3"}]' data-config='{"targeting":{"Site":"United States","mURL":"https%3a%2f%2fwww.monster.com%2fjobs%2fsearch%2f%3fq%3dData-Scientist%26where%3dNew-Delhi","lid":"497","Page":"Job Search Results","mesco":[1500152001001]},"member":3525}' data-mux="apasAds">
#   </div>
# ...

# %%
# Find Elements by HTML Class Name
job_elems = results.find_all('section', class_='card-content')

# %%
for job_elem in job_elems:
    print(job_elem, end='\n'*2)
# Out:
# <section class="card-content">
# <div class="flex-row">
# <div class="summary">
# <p>Showing Data Scientist jobs</p>
# </div>
# <i aria-hidden="true" class="icon icon-magnify"></i>
# </div>
# </section>
#
# <section class="card-content" data-jobid="225295612" data-postingid="9dd258a9-01df-42d7-bf4e-9d819e90d774" onclick="MKImpressionTrackingMouseDownHijack(this, event)">
# <div class="flex-row">
# <div class="mux-company-logo thumbnail"></div>
# <div class="summary">
# <header class="card-header">
# ...

# %%
for job_elem in job_elems:
    # Each job_elem is a new BeautifulSoup object.
    # You can use the same methods on it as you did before.
    title_elem = job_elem.find('h2', class_='title')
    company_elem = job_elem.find('div', class_='company')
    location_elem = job_elem.find('div', class_='location')
    print(title_elem)
    print(company_elem)
    print(location_elem)
    print()
# Out:
# None
# None
# None
#
# ...

# %%
for job_elem in job_elems:
    title_elem = job_elem.find('h2', class_='title')
    company_elem = job_elem.find('div', class_='company')
    location_elem = job_elem.find('div', class_='location')
    if None in (title_elem, company_elem, location_elem):
        continue
    print(title_elem.text.strip())
    print(company_elem.text.strip())
    print(location_elem.text.strip())
    print()
# Out:
# Advanced Data Scientist
# Honeywell
# Atlanta, GA
#
# Engineering and Data Scientist Professionals
# Engineering Technology Associates
# Troy, MI
#
# Senior Data Scientist
# Quicken Loans, LLC
# Detroit, MI
#
# Data Scientist
# Prestige Financial Services
# Draper, UT
#
# Data Scientist
# Vungle, Inc.
# San Francisco, CA
#
# Data Scientist
# Naval Nuclear Laboratory
# Niskayuna, NY
#
# Intel Mission Analytics/Data Scientist (TS//SCI)
# IBM
# Arlington, VA
#
# Senior Data Scientist / Engineer
# AMI Group, LLC
# Chicago, IL
#
# TECHNOLOGY ENGINEER - DATA SCIENTIST
# PSEG
# Newark, NJ
#
# Data Scientist
# West Virginia University
# Morgantown, WV
#
# Data Scientist
# Walker & Dunlop
# Chicago, IL
#
# Data Scientist
# Odyssey Systems Consulting Group, Ltd.
# Colorado Springs, CO
#
# Data Scientist
# LRS
# Maryland Heights, MO
#
# Sr. Data Scientist
# Sally Beauty
# Denton, TX
#
# Lead Data Scientist
# Michael Page
# New York, NY
#
# Data Scientist - Network Analytics - Flexible Location
# ...

# %%
# Find Elements by Class Name and Text Content
datascientist_jobs = results.find_all('h2', string='Data Scientist')

# %%
datascientist_jobs = results.find_all('h2',string=lambda text: 'data' in text.lower())

# %%
print(len(datascientist_jobs))
# Out:
# 25

# %%
# Extract Attributes From HTML Elements
python_jobs = results.find_all('h2',
                               string=lambda text: "data" in text.lower())

for p_job in python_jobs:
    link = p_job.find('a')['href']
    print(p_job.text.strip())
    print(f"Apply here: {link}\n")
# Out:
# Advanced Data Scientist
# Apply here: https://job-openings.monster.com/advanced-data-scientist-atlanta-ga-us-honeywell/225295612
#
# Engineering and Data Scientist Professionals
# Apply here: https://job-openings.monster.com/engineering-data-scientist-professionals-troy-mi-us-engineering-technology-associates/208176551
#
# Senior Data Scientist
# Apply here: https://job-openings.monster.com/senior-data-scientist-detroit-mi-us-quicken-loans-llc/328e4fc1-5196-4964-99fb-65ef1ec7dd0b
#
# Data Scientist
# Apply here: https://job-openings.monster.com/data-scientist-draper-ut-us-prestige-financial-services/225273223
#
# Data Scientist
# Apply here: https://job-openings.monster.com/data-scientist-san-francisco-ca-us-vungle-inc/225073272
#
# Data Scientist
# Apply here: https://job-openings.monster.com/data-scientist-niskayuna-ny-us-naval-nuclear-laboratory/682b65c9-3cb4-4e2f-b870-cecb0fb45c3c
#
# Intel Mission Analytics/Data Scientist (TS//SCI)
# ...
